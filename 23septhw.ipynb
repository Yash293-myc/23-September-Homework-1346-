# %% [markdown]
# # Homework do atleast 20 different slicing operation on your name
# ## Name = Yash Sharad Songire

# %%
s = "Yash Sharad Songire"
print(s[0:4:1])
# Out:
# Yash

# %%
print(s[0:17:2])
print(s[-1:-16:-1])
# Out:
# Ys hrdSni
# erignoS darahS

# %%
print(s[-16:-2:1])
print(s[13:17:2])
# Out:
# h Sharad Songi
# og

# %%
print(s[0:4])
print(s[5:11])
print(s[12:19])
# Out:
# Yash
# Sharad
# Songire

# %%
print(s[:4])
print(s[5:])
print(s[:11])
# Out:
# Yash
# Sharad Songire
# Yash Sharad

# %%
print(s[12:])
print(s[0:19:2])
print(s[1:19:2])
# Out:
# Songire
# Ys hrdSnie
# ahSaa ogr

# %%
print(s[::-1])
print(s[18:11:-1])
print(s[10:4:-1])
# Out:
# erignoS darahS hsaY
# erignoS
# darahS

# %%
print(s[3:0:-1])
print(s[-7:])
print(s[-7:-1])
# Out:
# hsa
# Songire
# Songir

# %%
print(s[-19:-12])
print(s[-1:-10:-2])
# Out:
# Yash Sh
# einSd

# %%
s = "YASH SHARAD SONGIRE"

print(s[2:8])
print(s[7:13])
# Out:
# SH SHA
# ARAD S

# %%
print(s[3:15])
print(s[4:10])
# Out:
# H SHARAD SON
#  SHARA

# %%
print(s[::2])
print(s[::3])
# Out:
# YS HRDSNIE
# YHHASGE

# %%
print(s[1::2])
print(s[2::3])
# Out:
# AHSAA OGR
# SSR NR

# %%
print(s[8:15])
print(s[6:14])
# Out:
# RAD SON
# HARAD SO

# %%
print(s[-1:])
print(s[-5:])
# Out:
# E
# NGIRE

# %%
print(s[-10:-5])
print(s[-15:-8])
# Out:
# AD SO
#  SHARAD

# %%
print(s[15:5:-1])
print(s[18:10:-2])
# Out:
# GNOS DARAH
# EINS

# %%
print(s[10:0:-2])
print(s[14:4:-3])
# Out:
# DRH S
# N RS

# %%
print(s[:])
print(s[::1])
# Out:
# YASH SHARAD SONGIRE
# YASH SHARAD SONGIRE

# %%
print(s[-2::-1])
# Out:
# RIGNOS DARAHS HSAY
